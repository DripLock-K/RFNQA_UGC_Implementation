# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("last final feature matrix.csv")

# %%
df.shape
# Out:
# (7199, 18)

# %%
df.head()
# Out:
#    avg_ti  avg_si  max_si  max_ti  min_si  min_ti  std_si  std_ti   blur_avg  \
# 0  40.795  60.386  93.294  53.156  33.686  28.947  14.221   4.622  14.394080
# 1  40.727  60.085  93.157  53.104  33.331  28.889  14.214   4.624  13.991863
# 2  40.630  59.600  93.082  53.035  32.815  28.802  14.232   4.622  13.414089
# 3  40.434  58.518  92.741  52.846  32.120  28.703  14.198   4.613  12.510922
# 4  39.999  56.558  91.830  52.525  31.027  28.507  14.025   4.586  11.186051
#
#    blur_min   blur_max   blur_std    bitrate  width  height  MSCN_mean  \
# 0  4.070789  69.011503  11.760994  101870043    720    1280   1.293989
# 1  3.948163  68.988884  11.085990   12541643    720    1280   1.295524
# 2  3.731166  67.451359  10.648622    6876293    720    1280   1.294845
# 3  3.503390  63.624180  10.022086    3654494    720    1280   1.295742
# 4  3.238184  54.358755   8.876915    1915182    720    1280   1.295060
#
#    MSCN_std  train__mos
# 0  0.406865      4.6552
# 1  0.402185      4.3793
# ...

# %%
df.tail()
# Out:
#       avg_ti  avg_si  max_si  max_ti  min_si  min_ti  std_si  std_ti  \
# 7194  27.974  35.638  53.672  87.940  17.232   0.115  10.918  21.724
# 7195  27.919  34.902  52.677  87.965  16.846   0.115  10.879  21.656
# 7196  27.789  33.321  50.560  87.831  15.785   0.384  10.737  21.462
# 7197  27.518  31.312  47.760  87.856  15.281   0.331   9.916  21.007
# 7198  26.988  28.540  42.603  87.253  14.551   1.041   8.138  19.939
#
#       blur_avg  blur_min  blur_max  blur_std  bitrate  width  height  \
# 7194  3.029333  1.242100  5.326973  1.308409  1177357    720    1280
# 7195  2.986351  1.145371  5.354820  1.349036   764574    720    1280
# 7196  2.898089  1.092699  5.338250  1.382876   522809    720    1280
# 7197  2.804782  1.082220  5.523307  1.395692   375307    720    1280
# 7198  2.682655  1.104362  4.994645  1.192732   266621    720    1280
#
#       MSCN_mean  MSCN_std  train__mos
# 7194   1.296730  0.397731      4.0294
# 7195   1.296050  0.399918      3.6765
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7199 entries, 0 to 7198
# Data columns (total 18 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   avg_ti      7199 non-null   float64
#  1   avg_si      7199 non-null   float64
#  2   max_si      7199 non-null   float64
#  3   max_ti      7199 non-null   float64
#  4   min_si      7199 non-null   float64
#  5   min_ti      7199 non-null   float64
#  6   std_si      7199 non-null   float64
#  7   std_ti      7199 non-null   float64
#  8   blur_avg    7199 non-null   float64
#  9   blur_min    7199 non-null   float64
#  10  blur_max    7199 non-null   float64
#  11  blur_std    7199 non-null   float64
#  12  bitrate     7199 non-null   int64
#  13  width       7199 non-null   int64
#  14  height      7199 non-null   int64
#  15  MSCN_mean   7199 non-null   float64
#  16  MSCN_std    7199 non-null   float64
#  17  train__mos  7199 non-null   float64
# dtypes: float64(15), int64(3)
# ...

# %%
df.describe()
# Out:
#             avg_ti       avg_si       max_si       max_ti       min_si  \
# count  7199.000000  7199.000000  7199.000000  7199.000000  7199.000000
# mean     14.688666    56.936457    64.883634    32.963604    47.111641
# std       8.421858    23.977533    25.446484    18.583464    24.084725
# min       0.798000     9.872000    11.977000     2.877000     0.000000
# 25%       8.572500    38.253000    45.330000    19.252500    28.059500
# 50%      13.308000    54.008000    62.232000    29.437000    44.306000
# 75%      18.569000    72.976000    82.725000    41.617000    62.944500
# max      61.228000   157.234000   166.480000   107.500000   147.804000
#
#             min_ti       std_si       std_ti     blur_avg     blur_min  \
# count  7199.000000  7199.000000  7199.000000  7199.000000  7199.000000
# mean      4.328074     4.325604     5.784009    12.710057     8.499264
# std       5.662228     3.984642     3.608906    16.465435    10.874152
# ...

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.head()
# Out:
#    avg_ti  avg_si  max_si  max_ti  min_si  min_ti  std_si  std_ti   blur_avg  \
# 0  40.795  60.386  93.294  53.156  33.686  28.947  14.221   4.622  14.394080
# 1  40.727  60.085  93.157  53.104  33.331  28.889  14.214   4.624  13.991863
# 2  40.630  59.600  93.082  53.035  32.815  28.802  14.232   4.622  13.414089
# 3  40.434  58.518  92.741  52.846  32.120  28.703  14.198   4.613  12.510922
# 4  39.999  56.558  91.830  52.525  31.027  28.507  14.025   4.586  11.186051
#
#    blur_min   blur_max   blur_std    bitrate  width  height  MSCN_mean  \
# 0  4.070789  69.011503  11.760994  101870043    720    1280   1.293989
# 1  3.948163  68.988884  11.085990   12541643    720    1280   1.295524
# 2  3.731166  67.451359  10.648622    6876293    720    1280   1.294845
# 3  3.503390  63.624180  10.022086    3654494    720    1280   1.295742
# 4  3.238184  54.358755   8.876915    1915182    720    1280   1.295060
#
#    MSCN_std  train__mos
# 0  0.406865      4.6552
# 1  0.402185      4.3793
# ...

# %%
X = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state = 42,test_size=.11)

# %%
X_train.shape
# Out:
# (6407, 17)

# %%
y_train.shape
# Out:
# (6407,)

# %%
from sklearn.neural_network import MLPRegressor
from sklearn.datasets import make_regression
regr = MLPRegressor(random_state=42, max_iter=500).fit(X_train, y_train)
regr.predict(X_test[:2])
# Out:
# array([ -4.47439958, -12.79356559])

# %%
regr.score(X_test, y_test)
# Out:
# -1701.752913225533

# %%
y_pred = regr.predict(X_test)

# %%
y_pred
# Out:
# array([-4.47439958e+00, -1.27935656e+01, -3.10355515e+00, -1.25258785e+02,
#        -1.23641158e+01,  2.36791317e+00, -8.88805265e+00, -1.56994779e+02,
#        -1.51947431e+01, -1.12021917e+02, -8.88565571e+01, -2.89520638e+00,
#        -2.74996120e+01, -1.32391483e+02,  4.02348061e+01, -4.69764011e+01,
#         4.01469795e+01, -8.65050754e+00, -3.50357068e+00, -1.13606736e+02,
#        -1.73852503e+02, -2.76565458e+01, -1.62485412e+01, -1.11404226e+01,
#        -2.82057044e+01, -9.48078214e+00, -9.25976384e+00, -3.16002328e+00,
#        -7.04740956e+00, -1.18239905e+01, -2.48522383e+01, -1.44885756e+01,
#         2.73688828e+01, -1.81976344e+01,  3.33226252e+01, -1.23555304e+02,
#        -1.74540332e+01, -1.31031979e+01,  3.03590652e+00, -1.23284754e+01,
#        -1.84738249e+00, -4.16302494e+00, -8.33452734e+00, -1.58210085e+02,
#        -1.36420800e+02, -9.38805083e+00, -8.27032227e+00, -1.48065189e+02,
# ...

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test,y_pred)
# Out:
# 2678.9960365300794

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test, y_pred)
# Out:
# 28.75057378266503

# %%
from sklearn.metrics import mean_absolute_error
print("MAE",mean_absolute_error(y_test,y_pred))
# Out:
# MAE 1674.1834045443643

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test,y_pred)
print(r2) #this says this model R2 score is between zero and one like 0.8 which means your model is capable to explain 80 per cent of the variance of data
# Out:
# -30331578.110232178

# %%
corelation = df.corr(method='pearson')
print(corelation)
# Out:
#               avg_ti    avg_si    max_si    max_ti    min_si    min_ti  \
# avg_ti      1.000000  0.305990  0.424699  0.600909  0.110245  0.694068
# avg_si      0.305990  1.000000  0.957783  0.132615  0.918085  0.205860
# max_si      0.424699  0.957783  1.000000  0.265960  0.818260  0.270568
# max_ti      0.600909  0.132615  0.265960  1.000000 -0.059128  0.204457
# min_si      0.110245  0.918085  0.818260 -0.059128  1.000000  0.086530
# min_ti      0.694068  0.205860  0.270568  0.204457  0.086530  1.000000
# std_si      0.471825  0.132992  0.371875  0.510450 -0.182862  0.249562
# std_ti      0.431120  0.112760  0.216865  0.826700 -0.027472 -0.100686
# blur_avg    0.352758  0.756678  0.731026  0.117182  0.671759  0.253110
# blur_min    0.161107  0.751587  0.677753 -0.008756  0.799123  0.112252
# blur_max    0.439434  0.656661  0.701404  0.173669  0.537084  0.323690
# blur_std    0.467459  0.418391  0.515363  0.235538  0.242335  0.328795
# ...

# %%
corelation = df.corr(method='spearman')
print(corelation)
# Out:
#               avg_ti    avg_si    max_si    max_ti    min_si    min_ti  \
# avg_ti      1.000000  0.286516  0.399861  0.731410  0.105766  0.471197
# avg_si      0.286516  1.000000  0.957375  0.191083  0.917693  0.130415
# max_si      0.399861  0.957375  1.000000  0.318784  0.817309  0.174261
# max_ti      0.731410  0.191083  0.318784  1.000000 -0.003866  0.108325
# min_si      0.105766  0.917693  0.817309 -0.003866  1.000000  0.054097
# min_ti      0.471197  0.130415  0.174261  0.108325  0.054097  1.000000
# std_si      0.557306  0.140829  0.339481  0.591853 -0.144582  0.215978
# std_ti      0.555091  0.114023  0.217976  0.865752 -0.025599 -0.157866
# blur_avg    0.323554  0.947526  0.926376  0.183833  0.854592  0.193427
# blur_min    0.140357  0.889968  0.801097 -0.005200  0.957845  0.103063
# blur_max    0.407322  0.898318  0.939764  0.266510  0.766000  0.230913
# blur_std    0.526440  0.717336  0.833743  0.430648  0.494314  0.258099
# ...
