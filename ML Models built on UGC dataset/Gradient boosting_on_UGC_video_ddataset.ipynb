# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("C:\\Users\\krishna\\OneDrive\\Desktop\\Krishna_thesis\\final work\\last final feature matrix.csv")

# %%
df.shape
# Out:
# (1116, 19)

# %%
df.head()
# Out:
#     avg_si  avg_ti   max_si  max_ti  min_si  min_ti  num_frames  std_si  \
# 0   67.761  11.486  149.348  43.906   0.000   0.000         599  56.717
# 1  127.930   8.846  161.529  70.356  92.198   0.007         599  14.157
# 2  114.687   3.601  139.886  22.136  86.393   0.000         600  13.476
# 3   93.078   7.374  110.246  69.041  75.806   0.000         600   9.397
# 4   82.019  21.565  105.680  39.132  52.316   0.003         599  17.192
#
#    std_ti   bitrate  width  height     blur_avg     blur_min      blur_max  \
# 0  14.722  39455067   1920    1080   487.469110     0.000000   1433.735087
# 1  14.491  20173043   1920    1080  1996.931966   554.755396  10293.566930
# 2   2.806  35246779   1920    1080   754.504431   167.188913   1942.206195
# 3   7.805   4884280   1920    1080  2995.681891  2161.869410   3685.894480
# 4  12.612  45925284   1920    1080   220.564283    67.775987    415.174225
#
#       blur_std  mscn_mean  mscn_std   MOS
# ...

# %%
df.tail()
# Out:
#        avg_si  avg_ti   max_si  max_ti   min_si  min_ti  num_frames  std_si  \
# 1111  121.056  37.814  138.947  94.695   51.325   0.000         600  19.794
# 1112   14.708  18.318   69.087  63.829    3.315   3.173         600  14.349
# 1113  133.745  43.696  139.519  70.818  106.505   0.000         599   2.871
# 1114   85.111  27.500  105.933  97.553   17.452   0.009         599  20.121
# 1115   39.289  22.331  105.462  98.805    8.104   0.127         600  28.327
#
#       std_ti   bitrate  width  height     blur_avg    blur_min     blur_max  \
# 1111  32.814  15206598   1280     720  1758.222462   62.608977  4423.858075
# 1112  11.668  29182761   1280     720    47.318120    1.001485   472.889238
# 1113  23.921  22056747    732     720  3056.573031  839.414998  3548.119565
# 1114  15.206  21078458   1280     720   651.112704    9.664105  1115.456340
# 1115  17.525  20255127   1280     720   315.642088    6.202926  2796.182781
#
#          blur_std  mscn_mean  mscn_std   MOS
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1116 entries, 0 to 1115
# Data columns (total 19 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   avg_si      1116 non-null   float64
#  1   avg_ti      1116 non-null   float64
#  2   max_si      1116 non-null   float64
#  3   max_ti      1116 non-null   float64
#  4   min_si      1116 non-null   float64
#  5   min_ti      1116 non-null   float64
#  6   num_frames  1116 non-null   int64
#  7   std_si      1116 non-null   float64
#  8   std_ti      1116 non-null   float64
#  9   bitrate     1116 non-null   int64
#  10  width       1116 non-null   int64
#  11  height      1116 non-null   int64
#  12  blur_avg    1116 non-null   float64
#  13  blur_min    1116 non-null   float64
#  14  blur_max    1116 non-null   float64
#  15  blur_std    1116 non-null   float64
#  16  mscn_mean   1116 non-null   float64
#  17  mscn_std    1116 non-null   float64
# ...

# %%
df.describe()
# Out:
#             avg_si       avg_ti       max_si       max_ti       min_si  \
# count  1116.000000  1116.000000  1116.000000  1116.000000  1116.000000
# mean     83.312731    15.637716   113.802804    58.066431    49.183142
# std      43.767873    11.714413    53.856913    33.499498    43.980186
# min       3.245000     0.003000     3.636000     0.252000     0.000000
# 25%      52.606000     6.466500    78.222250    32.140250    14.834000
# 50%      78.401000    13.054500   107.270000    54.737000    40.935000
# 75%     105.881000    22.503750   141.329000    83.468750    72.119000
# max     301.909000    73.774000   391.023000   167.639000   301.614000
#
#             min_ti   num_frames       std_si       std_ti       bitrate  \
# count  1116.000000  1116.000000  1116.000000  1116.000000  1.116000e+03
# mean      1.067750   594.935484    15.856659     9.996179  3.408101e+07
# std       3.548848    35.748265    15.472622     6.751879  5.875463e+07
# ...

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.head()
# Out:
#     avg_si  avg_ti   max_si  max_ti  min_si  min_ti  num_frames  std_si  \
# 0   67.761  11.486  149.348  43.906   0.000   0.000         599  56.717
# 1  127.930   8.846  161.529  70.356  92.198   0.007         599  14.157
# 2  114.687   3.601  139.886  22.136  86.393   0.000         600  13.476
# 3   93.078   7.374  110.246  69.041  75.806   0.000         600   9.397
# 4   82.019  21.565  105.680  39.132  52.316   0.003         599  17.192
#
#    std_ti   bitrate  width  height     blur_avg     blur_min      blur_max  \
# 0  14.722  39455067   1920    1080   487.469110     0.000000   1433.735087
# 1  14.491  20173043   1920    1080  1996.931966   554.755396  10293.566930
# 2   2.806  35246779   1920    1080   754.504431   167.188913   1942.206195
# 3   7.805   4884280   1920    1080  2995.681891  2161.869410   3685.894480
# 4  12.612  45925284   1920    1080   220.564283    67.775987    415.174225
#
#       blur_std  mscn_mean  mscn_std   MOS
# ...

# %%
X = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
# Import models and utility functions
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error as MSE
from sklearn import datasets
  
# Setting SEED for reproducibility
SEED = 42
  
# Importing the dataset 
#bike = datasets.load_bike()
#X, y = bike.data, bike.target
  
# Splitting dataset
train_X, test_X, train_y, test_y = train_test_split(X, y, test_size = 0.11, random_state = SEED)
  
# Instantiate Gradient Boosting Regressor
gbr = GradientBoostingRegressor(n_estimators = 200, max_depth = 1, random_state = SEED)
  
# Fit to training set
gbr.fit(train_X, train_y)
  
# Predict on test set
pred_y = gbr.predict(test_X)
  
# test set RMSE
test_rmse = MSE(test_y, pred_y) ** (1 / 2)
  
# Print rmse
print('RMSE test set: {:.2f}'.format(test_rmse))
# Out:
# RMSE test set: 0.49

# %%
train_y
# Out:
# 922     2.609
# 867     3.591
# 1049    3.887
# 1073    2.479
# 587     3.829
#         ...
# 466     3.846
# 121     4.235
# 1044    4.212
# 1095    2.588
# 860     3.053
# Name: MOS , Length: 993, dtype: float64

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(test_y,pred_y)
# Out:
# 0.23558764768122575

# %%
import math
MSE = np.square(np.subtract(test_y,pred_y)).mean() 
 
RMSE = math.sqrt(MSE)
print("Root Mean Square Error:\n")
print(RMSE)
# Out:
# Root Mean Square Error:
#
# 0.4853737196029733

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(test_y,pred_y)
# Out:
# 0.37636147255975355

# %%
from sklearn.metrics import mean_absolute_error
print("MAE",mean_absolute_error(test_y,pred_y))
# Out:
# MAE 0.37636147255975355

# %%
from sklearn.metrics import r2_score
r2 = r2_score(test_y,pred_y)
print(r2) #this says this model R2 score is between zero and one like 0.8 which means your model is capable to explain 80 per cent of the variance of data
# Out:
# 0.43049862758910096

# %%
import pandas as pd
from scipy.stats import pearsonr
corr,_=pearsonr(test_y,pred_y)
print('Pearsons correlation: %.3f' % corr)
# Out:
# Pearsons correlation: 0.670

# %%
import scipy.stats
def spearmans_rank_correlation(x, y):
     
    # Calculate the rank of x's
    xranks = pd.Series(x).rank()
    print("Rankings of X:")
    print(xranks)
     
    # Calculate the ranking of the y's
    yranks = pd.Series(y).rank()
    print("Rankings of Y:")
    print(yranks)
     
    # Calculate Pearson's correlation coefficient on the ranked versions of the data
    print("Spearman's Rank correlation:",scipy.stats.pearsonr(xranks, yranks)[0])
 
# Call the function
spearmans_rank_correlation(test_y,pred_y)
# Out:
# Rankings of X:
# 993     71.0
# 101      3.0
# 486     80.0
# 862     95.0
# 1075    13.0
#         ...
# 1085    53.0
# 23       4.0
# 721     68.0
# 367     62.0
# 541     96.0
# Name: MOS , Length: 123, dtype: float64
# Rankings of Y:
# 0       79.0
# 1        1.0
# 2      107.5
# 3       51.0
# 4       30.5
#        ...
# 118     48.0
# 119     17.0
# 120     63.0
# 121     37.0
# 122     96.0
# Length: 123, dtype: float64
# Spearman's Rank correlation: 0.694922714572508

# %%
from scipy.stats import kendalltau
corr, _ = kendalltau(test_y,pred_y)
print('Kendall Rank correlation: %.5f' % corr)
# Out:
# Kendall Rank correlation: 0.50734
